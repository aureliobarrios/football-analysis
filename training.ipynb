# %% [markdown]
# ### Imports

# %%
import os
import shutil
from dotenv import load_dotenv
from ultralytics import YOLO
from roboflow import Roboflow

load_dotenv()

ROBO_API_KEY = os.environ.get("ROBO_API_KEY")

# %% [markdown]
# ### Dataset

# %%
#create a Roboflow instance
rf = Roboflow(api_key=ROBO_API_KEY)
#create a Roboflow instance project
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
#create a project version
version = project.version(1)
#download the Roboflow dataset that will be used for training
dataset = version.download("yolov11")
#reformat data for Roboflow workflow
# shutil.move('football-players-detection-1/train', 'football-players-detection-1/football-players-detection-1/train')
# shutil.move('football-players-detection-1/test', 'football-players-detection-1/football-players-detection-1/test')
# shutil.move('football-players-detection-1/valid', 'football-players-detection-1/football-players-detection-1/valid')
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %% [markdown]
# ### YOLO Training

# %%
#get the YOLO model
model = YOLO("yolo11n.pt")

# %%
#train the model
results = model.train(data=f"{dataset.location}/data.yaml", epochs=50, device="mps")
# Out:
# Ultralytics 8.3.204 🚀 Python-3.13.7 torch-2.8.0 MPS (Apple M4)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/Users/ari/GitHub/football-analysis/football-players-detection-1/data.yaml, degrees=0.0, deterministic=True, device=mps, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/Users/ari/GitHub/football-analysis/runs/detect/train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    431452  ultralytics.nn.modules.head.Detect           [4, [64, 128, 256]]
# YOLO11n summary: 181 layers, 2,590,620 parameters, 2,590,604 gradients, 6.4 GFLOPs
#
# Transferred 448/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 6540.1±1725.4 MB/s, size: 226.0 KB)
# train: Scanning /Users/ari/GitHub/football-analysis/football-players-detection-1/train/labels.cache... 612 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 612/612 3.1Mit/s 0.0s0s
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 7839.7±1110.2 MB/s, size: 209.9 KB)
# val: Scanning /Users/ari/GitHub/football-analysis/football-players-detection-1/valid/labels.cache... 38 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 38/38 294.6Kit/s 0.0s
# Plotting labels to /Users/ari/GitHub/football-analysis/runs/detect/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to /Users/ari/GitHub/football-analysis/runs/detect/train
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      6.63G      1.753      2.686     0.8857        203        640: 100% ━━━━━━━━━━━━ 39/39 0.9it/s 41.4s1.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.5it/s 4.0s9.6s
#                    all         38        905   9.27e-05   0.000663   4.77e-05   1.44e-05
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50       6.6G      1.607      1.314     0.8558        102        640: 100% ━━━━━━━━━━━━ 39/39 0.9it/s 43.4s0.9ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.5it/s 4.2s11.6s
#                    all         38        905     0.0342      0.277      0.165     0.0744
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      5.49G      1.521      1.161     0.8475        185        640: 100% ━━━━━━━━━━━━ 39/39 0.9it/s 45.2s1.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.5it/s 4.3s11.8s
#                    all         38        905      0.914      0.186      0.248      0.134
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      6.49G      1.441      1.067     0.8341        176        640: 100% ━━━━━━━━━━━━ 39/39 0.9it/s 45.6s1.1ss
# WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.4it/s 5.7s15.4s
#                    all         38        905      0.836      0.238      0.282      0.163
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      6.51G      1.336     0.9775     0.8285         76        640: 100% ━━━━━━━━━━━━ 39/39 0.8it/s 50.1s1.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.4it/s 5.3s14.9s
#                    all         38        905      0.779      0.276       0.32      0.172
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      6.57G      1.382     0.9361     0.8317        123        640: 100% ━━━━━━━━━━━━ 39/39 0.8it/s 47.0s1.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.4it/s 5.0s13.9s
#                    all         38        905      0.749      0.303      0.354      0.206
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      6.59G      1.326     0.8903      0.826         77        640: 100% ━━━━━━━━━━━━ 39/39 0.8it/s 48.4s1.2ss
# WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.3it/s 5.8s15.2s
#                    all         38        905      0.663      0.381      0.406      0.251
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      6.61G      1.283     0.8291     0.8237        164        640: 100% ━━━━━━━━━━━━ 39/39 0.9it/s 45.6s1.2ss
# WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.4it/s 5.4s15.2s
#                    all         38        905      0.768      0.417       0.47      0.288
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50       5.5G       1.27     0.8116     0.8236         76        640: 100% ━━━━━━━━━━━━ 39/39 0.9it/s 44.8s1.1ss
# WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.4it/s 5.6s15.7s
#                    all         38        905      0.761      0.466      0.509      0.267
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50      5.55G       1.36     0.8153     0.8235        173        640: 100% ━━━━━━━━━━━━ 39/39 0.9it/s 44.9s1.2ss
# WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.4it/s 5.5s14.6s
#                    all         38        905      0.767      0.393      0.426      0.249
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50      6.39G      1.288      0.766     0.8223        215        640: 100% ━━━━━━━━━━━━ 39/39 0.8it/s 46.3s1.1ss
# WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.3it/s 6.1s17.0s
#                    all         38        905       0.75      0.397      0.432      0.279
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50      5.68G      1.233     0.7241      0.817        203        640: 100% ━━━━━━━━━━━━ 39/39 0.8it/s 47.3s1.3ss
# WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.2it/s 9.2s21.3s
#                    all         38        905      0.774      0.305      0.323      0.207
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50      7.43G      1.214     0.7117     0.8155        144        640: 100% ━━━━━━━━━━━━ 39/39 0.8it/s 49.2s1.3ss
# WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.2it/s 10.1s4.6s
#                    all         38        905      0.839      0.319      0.357      0.225
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50      6.39G      1.229     0.6991     0.8163        219        640: 100% ━━━━━━━━━━━━ 39/39 0.8it/s 48.8s1.2ss
# WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.2it/s 10.7s6.0s
#                    all         38        905      0.784      0.344      0.368      0.232
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50       6.3G      1.224     0.6858     0.8121        236        640: 100% ━━━━━━━━━━━━ 39/39 0.8it/s 46.4s1.2ss
# WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.2it/s 10.7s6.4s
#                    all         38        905      0.846      0.354      0.389      0.228
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/50       6.3G      1.238     0.6823     0.8117        116        640: 100% ━━━━━━━━━━━━ 39/39 0.8it/s 46.6s1.3ss
# WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.2it/s 11.5s8.2s
#                    all         38        905      0.895      0.322      0.377      0.229
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/50      6.32G      1.175     0.6554      0.811        149        640: 100% ━━━━━━━━━━━━ 39/39 0.8it/s 47.6s1.4ss
# WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.2it/s 10.9s8.8s
#                    all         38        905      0.817      0.378      0.415      0.266
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/50       5.4G       1.18     0.6493     0.8086        192        640: 100% ━━━━━━━━━━━━ 39/39 0.9it/s 45.4s1.1ss
# WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.2it/s 9.5s25.7s
#                    all         38        905      0.797      0.372      0.392      0.253
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/50      6.37G       1.13     0.6348     0.8084        201        640: 100% ━━━━━━━━━━━━ 39/39 0.8it/s 48.5s1.4ss
# WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.2it/s 12.2s33.4s
#                    all         38        905       0.78      0.482      0.527      0.333
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/50      5.29G      1.134      0.629     0.8094        128        640: 100% ━━━━━━━━━━━━ 39/39 0.8it/s 48.4s1.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.2it/s 10.3s9.2s
#                    all         38        905      0.835      0.591      0.631      0.407
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/50      6.31G      1.133     0.6195     0.8055        140        640: 100% ━━━━━━━━━━━━ 39/39 0.8it/s 49.3s1.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.2it/s 11.3s3.1s
#                    all         38        905      0.825       0.59      0.637      0.408
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/50      6.28G      1.183     0.6331     0.8075        185        640: 100% ━━━━━━━━━━━━ 39/39 0.8it/s 49.1s1.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.2it/s 8.8s24.7s
#                    all         38        905      0.883      0.534      0.633      0.406
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/50      6.44G      1.131     0.6019     0.8049        256        640: 100% ━━━━━━━━━━━━ 39/39 0.8it/s 48.9s1.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.3it/s 7.5s20.9s
#                    all         38        905       0.84      0.621      0.658      0.439
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/50      6.31G       1.13     0.6001      0.804        116        640: 100% ━━━━━━━━━━━━ 39/39 0.9it/s 44.0s1.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.2it/s 8.4s22.9s
#                    all         38        905      0.866      0.598      0.654      0.429
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/50      6.32G      1.101     0.5847     0.8054        198        640: 100% ━━━━━━━━━━━━ 39/39 0.8it/s 47.8s1.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.2it/s 9.1s26.4s
#                    all         38        905      0.863      0.583      0.641      0.406
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/50      6.32G      1.119     0.5871     0.8058        185        640: 100% ━━━━━━━━━━━━ 39/39 0.8it/s 49.2s1.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.2it/s 9.8s26.5s
#                    all         38        905      0.884      0.589       0.66      0.419
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/50      6.29G      1.074     0.5642     0.8057        222        640: 100% ━━━━━━━━━━━━ 39/39 0.8it/s 47.4s1.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.2it/s 8.8s23.2s
#                    all         38        905      0.823       0.61      0.663      0.433
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/50      6.32G      1.134     0.5877     0.8023        263        640: 100% ━━━━━━━━━━━━ 39/39 0.8it/s 50.0s1.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.1it/s 36.0s9.9s
#                    all         38        905      0.795      0.559      0.641      0.412
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/50      7.32G      1.102     0.5749     0.8015        134        640: 100% ━━━━━━━━━━━━ 39/39 0.1it/s 6:141.8sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.3it/s 6.3s14.6s
#                    all         38        905      0.844      0.566      0.653      0.424
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/50      6.34G      1.084     0.5611     0.8033        111        640: 100% ━━━━━━━━━━━━ 39/39 0.2it/s 3:491.3sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.3it/s 6.7s18.3s
#                    all         38        905      0.877      0.588      0.663      0.426
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/50      6.32G      1.049     0.5525     0.8005        163        640: 100% ━━━━━━━━━━━━ 39/39 0.8it/s 46.0s1.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.3it/s 6.2s16.5s
#                    all         38        905      0.877      0.578      0.661      0.434
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/50      6.33G      1.061     0.5579      0.801        145        640: 100% ━━━━━━━━━━━━ 39/39 0.8it/s 48.5s1.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.2it/s 9.9s27.1s
#                    all         38        905      0.859       0.61       0.68      0.442
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/50      6.39G      1.064     0.5495     0.8003        190        640: 100% ━━━━━━━━━━━━ 39/39 0.9it/s 45.2s1.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.3it/s 7.9s21.5s
#                    all         38        905      0.793      0.608      0.676      0.437
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/50      6.32G      1.056     0.5475      0.799        184        640: 100% ━━━━━━━━━━━━ 39/39 0.9it/s 44.2s1.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.4it/s 4.9s12.8s
#                    all         38        905      0.838      0.598      0.664      0.433
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/50      7.32G      1.037     0.5395     0.7969        192        640: 100% ━━━━━━━━━━━━ 39/39 0.8it/s 46.0s1.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.7it/s 2.9s8.6s
#                    all         38        905      0.779      0.639      0.673      0.434
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/50      5.65G      1.036     0.5327     0.7997        222        640: 100% ━━━━━━━━━━━━ 39/39 0.9it/s 44.8s1.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.4it/s 4.6s13.9s
#                    all         38        905      0.771      0.624      0.689       0.43
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/50      6.34G      1.065      0.537      0.797        129        640: 100% ━━━━━━━━━━━━ 39/39 0.9it/s 42.0s1.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.5it/s 4.1s10.9s
#                    all         38        905      0.893      0.613       0.69      0.429
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/50      6.31G      1.023     0.5196     0.7968        189        640: 100% ━━━━━━━━━━━━ 39/39 0.9it/s 44.4s1.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.3it/s 5.9s17.6s
#                    all         38        905       0.82      0.636      0.682      0.442
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/50      6.32G      1.034     0.5257     0.7974        167        640: 100% ━━━━━━━━━━━━ 39/39 0.9it/s 43.7s1.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.3it/s 6.3s16.8s
#                    all         38        905      0.843      0.649      0.701      0.457
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50      5.79G      1.034     0.5259     0.7987        157        640: 100% ━━━━━━━━━━━━ 39/39 0.9it/s 45.5s1.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.3it/s 5.8s17.0s
#                    all         38        905      0.757      0.637      0.676      0.448
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50      5.47G     0.9725     0.5168     0.7979         93        640: 100% ━━━━━━━━━━━━ 39/39 0.5it/s 1:112.1sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.4it/s 4.9s15.7s
#                    all         38        905      0.774      0.605      0.674      0.437
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50      5.43G      0.948     0.5015      0.797         92        640: 100% ━━━━━━━━━━━━ 39/39 0.6it/s 1:051.6sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.6it/s 3.1s8.6s
#                    all         38        905       0.88        0.6      0.665      0.423
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50      5.43G      0.921     0.4867     0.7979         90        640: 100% ━━━━━━━━━━━━ 39/39 0.6it/s 1:042.0sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.6it/s 3.3s10.2s
#                    all         38        905      0.865      0.616      0.682      0.428
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50      4.43G      0.914     0.4839     0.7953         96        640: 100% ━━━━━━━━━━━━ 39/39 0.7it/s 59.8s1.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.7it/s 3.0s8.2s
#                    all         38        905       0.77      0.611      0.677      0.427
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50      5.43G     0.9355     0.4874     0.7958         92        640: 100% ━━━━━━━━━━━━ 39/39 0.6it/s 1:041.3sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.6it/s 3.4s9.8s
#                    all         38        905      0.661      0.673      0.671      0.422
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50      5.41G     0.9205     0.4782     0.7946         95        640: 100% ━━━━━━━━━━━━ 39/39 0.6it/s 1:041.4sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.4it/s 5.5s13.0s
#                    all         38        905      0.764      0.642      0.684      0.426
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50      5.44G     0.9005     0.4719     0.7938         92        640: 100% ━━━━━━━━━━━━ 39/39 0.7it/s 54.4s1.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.5it/s 3.7s9.6s
#                    all         38        905      0.791      0.659      0.702      0.432
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50      5.43G     0.8975     0.4688      0.796         92        640: 100% ━━━━━━━━━━━━ 39/39 0.7it/s 55.4s1.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.4it/s 4.7s10.9s
#                    all         38        905      0.763      0.673      0.697       0.43
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      5.44G     0.9025     0.4696     0.7948         94        640: 100% ━━━━━━━━━━━━ 39/39 0.7it/s 56.8s1.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.6it/s 3.6s8.3s
#                    all         38        905      0.674       0.64       0.68      0.422
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      5.44G     0.8939     0.4608     0.7928         93        640: 100% ━━━━━━━━━━━━ 39/39 0.7it/s 53.7s1.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.6it/s 3.3s9.3s
#                    all         38        905      0.681      0.654      0.686      0.442
#
# 50 epochs completed in 0.936 hours.
# Optimizer stripped from /Users/ari/GitHub/football-analysis/runs/detect/train/weights/last.pt, 5.4MB
# Optimizer stripped from /Users/ari/GitHub/football-analysis/runs/detect/train/weights/best.pt, 5.4MB
#
# Validating /Users/ari/GitHub/football-analysis/runs/detect/train/weights/best.pt...
# Ultralytics 8.3.204 🚀 Python-3.13.7 torch-2.8.0 MPS (Apple M4)
# YOLO11n summary (fused): 100 layers, 2,582,932 parameters, 0 gradients, 6.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.1it/s 24.0s1:07
#                    all         38        905      0.842      0.649      0.701      0.456
#                   ball         35         35      0.874     0.0571      0.121     0.0269
#             goalkeeper         27         27      0.817      0.926      0.952      0.652
#                 player         38        754      0.897      0.951      0.976      0.693
#                referee         38         89       0.78      0.663      0.755      0.454
# Speed: 0.2ms preprocess, 119.5ms inference, 0.0ms loss, 5.6ms postprocess per image
# Results saved to /Users/ari/GitHub/football-analysis/runs/detect/train
